# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_columns',120)

# %%
# !ls data
# Out:
# 2012-18_officialBoxScore.csv  metadata_officialBoxScore.pdf
# 2012-18_playerBoxScore.csv    metadata_playerBoxScore.pdf
# 2012-18_standings.csv         metadata_standing.pdf
# 2012-18_teamBoxScore.csv      metadata_teamBoxScore.pdf

# %%
official = pd.read_csv('data/2012-18_officialBoxScore.csv')
official.shape
# Out:
# (44284, 119)

# %%
official.head(1)
# Out:
#        gmDate gmTime  seasTyp    offLNm offFNm teamAbbr teamConf    teamDiv  \
# 0  2012-10-30  19:00  Regular  Brothers   Tony      WAS     East  Southeast
#
#   teamLoc teamRslt  teamMin  teamDayOff  teamPTS  teamAST  teamTO  teamSTL  \
# 0    Away     Loss      240           0       84       26      13       11
#
#    teamBLK  teamPF  teamFGA  teamFGM  teamFG%  team2PA  team2PM  team2P%  \
# 0       10      19       90       32   0.3556       58       24   0.4138
#
#    team3PA  team3PM  team3P%  teamFTA  teamFTM  teamFT%  teamORB  teamDRB  \
# 0       32        8     0.25       20       12      0.6       18       21
#
#    teamTRB  teamPTS1  teamPTS2  teamPTS3  teamPTS4  teamPTS5  teamPTS6  \
# 0       39        24        15        23        22         0         0
#
#    teamPTS7  teamPTS8  teamTREB%  teamASST%  teamTS%  teamEFG%  teamOREB%  \
# 0         0         0    41.9355      81.25   0.4251       0.4    33.3333
#
# ...

# %% [markdown]
# #### summary of what this dataset provides
#
# 1. Game date, time ,season type, home/away, win/loss,
# 2. officials name
# 3. team, team ids, team divison,  rating stats.
# 4. general playing. stats.
# 5. points in. that quarter
# 6. more advanced stats in ercentage.
# 7. same stats for oponenet too
#
# Stats of 44,284 games between 2012-2106
#
# **no null values** data is clean
#
# Ideas on how to augment data/process it:
# 1. turn date into datetime objects, and same with time.
# 2. drop seasType, since its all the samne value "Regular"
# 3. boolean teamConf(east,west), teamLoc(away, homme),...boolean all binary columns
# 4. teamDiv to categorical, only 6 uniaue values
#
# **how can this help our data?**
# can merge on gmDate, officials, adn team
#
# this can tell us how a player did in a game against another player.
# seems like this is gemnrally stats to merge for another table w/ players wince we are focusining on the other team

# %%
official.head()
# Out:
#        gmDate gmTime  seasTyp    offLNm    offFNm teamAbbr teamConf  \
# 0  2012-10-30  19:00  Regular  Brothers      Tony      WAS     East
# 1  2012-10-30  19:00  Regular     Smith   Michael      WAS     East
# 2  2012-10-30  19:00  Regular   Workman  Haywoode      WAS     East
# 3  2012-10-30  19:00  Regular  Brothers      Tony      CLE     East
# 4  2012-10-30  19:00  Regular     Smith   Michael      CLE     East
#
#      teamDiv teamLoc teamRslt  teamMin  teamDayOff  teamPTS  teamAST  teamTO  \
# 0  Southeast    Away     Loss      240           0       84       26      13
# 1  Southeast    Away     Loss      240           0       84       26      13
# 2  Southeast    Away     Loss      240           0       84       26      13
# 3    Central    Home      Win      240           0       94       22      21
# 4    Central    Home      Win      240           0       94       22      21
#
#    teamSTL  teamBLK  teamPF  teamFGA  teamFGM  teamFG%  team2PA  team2PM  \
# ...

# %%
#official.gmDate = pd.to_datetime(official.gmDate)
#official.gmTime = pd.to_timedelta(official.gmTime.map(lambda x: x + ':00'))
official.teamLoc = official.teamLoc.map(lambda x: 1 if x=='Home' else 0)
official = official.drop(['seasTyp'],axis=1)
official['teamAbbr'] = official['teamAbbr'].astype('category')
official.teamRslt = official.teamRslt.map(lambda x: 1 if x=='Win' else 0)

# %%
official.head()
# Out:
#        gmDate gmTime    offLNm    offFNm teamAbbr teamConf    teamDiv  \
# 0  2012-10-30  19:00  Brothers      Tony      WAS     East  Southeast
# 1  2012-10-30  19:00     Smith   Michael      WAS     East  Southeast
# 2  2012-10-30  19:00   Workman  Haywoode      WAS     East  Southeast
# 3  2012-10-30  19:00  Brothers      Tony      CLE     East    Central
# 4  2012-10-30  19:00     Smith   Michael      CLE     East    Central
#
#    teamLoc  teamRslt  teamMin  teamDayOff  teamPTS  teamAST  teamTO  teamSTL  \
# 0        0         0      240           0       84       26      13       11
# 1        0         0      240           0       84       26      13       11
# 2        0         0      240           0       84       26      13       11
# 3        1         1      240           0       94       22      21        7
# 4        1         1      240           0       94       22      21        7
#
#    teamBLK  teamPF  teamFGA  teamFGM  teamFG%  team2PA  team2PM  team2P%  \
# ...

# %%
official.to_csv('official_cleaned.csv')

# %%
official
# Out:
#            gmDate gmTime      offLNm    offFNm teamAbbr teamConf    teamDiv  \
# 0      2012-10-30  19:00    Brothers      Tony      WAS     East  Southeast
# 1      2012-10-30  19:00       Smith   Michael      WAS     East  Southeast
# 2      2012-10-30  19:00     Workman  Haywoode      WAS     East  Southeast
# 3      2012-10-30  19:00    Brothers      Tony      CLE     East    Central
# 4      2012-10-30  19:00       Smith   Michael      CLE     East    Central
# 5      2012-10-30  19:00     Workman  Haywoode      CLE     East    Central
# 6      2012-10-30  20:00   McCutchen     Monty      BOS     East   Atlantic
# 7      2012-10-30  20:00      Wright      Sean      BOS     East   Atlantic
# 8      2012-10-30  20:00  Fitzgerald      Kane      BOS     East   Atlantic
# 9      2012-10-30  20:00   McCutchen     Monty      MIA     East  Southeast
# 10     2012-10-30  20:00      Wright      Sean      MIA     East  Southeast
# ...

# %%
players = pd.read_csv('data/2012-18_playerBoxScore.csv')
standings = pd.read_csv('data/2012-18_standings.csv')

standings.rename(index=str, columns = {"stDate": "gmDate"}, inplace=True)

set(official.columns).difference(set(players.columns))
print(players.shape, standings.shape)
data = players.merge(standings, on = ["gmDate", "teamAbbr"])

print(players.shape, standings.shape, data.shape)
set(data.columns).difference(set(official.columns))

data = data.merge(official, on = ['gmDate', 'teamAbbr'])
print(data.shape)
data
# Out:
# (155713, 51) (29520, 39)
# (155713, 51) (29520, 39) (155106, 88)
# (465421, 204)
#             gmDate gmTime_x  seasTyp       playLNm   playFNm teamAbbr  \
# 0       2012-10-30    19:00  Regular         Price      A.J.      WAS
# 1       2012-10-30    19:00  Regular         Price      A.J.      WAS
# 2       2012-10-30    19:00  Regular         Price      A.J.      WAS
# 3       2012-10-30    19:00  Regular         Ariza    Trevor      WAS
# 4       2012-10-30    19:00  Regular         Ariza    Trevor      WAS
# 5       2012-10-30    19:00  Regular         Ariza    Trevor      WAS
# 6       2012-10-30    19:00  Regular        Okafor     Emeka      WAS
# 7       2012-10-30    19:00  Regular        Okafor     Emeka      WAS
# 8       2012-10-30    19:00  Regular        Okafor     Emeka      WAS
# 9       2012-10-30    19:00  Regular          Beal   Bradley      WAS
# 10      2012-10-30    19:00  Regular          Beal   Bradley      WAS
# ...

# %%
(data.memory_usage(deep=True) * 1e-6).sort_values(ascending=False)
# Out:
# playDispNm      33.118789
# gmDate          31.183207
# playBDate       31.183207
# teamDiv_x       30.331211
# teamDiv_y       30.331211
# opptDiv_x       30.329771
# opptDiv_y       30.329771
# playLNm         30.011539
# seasTyp         29.786944
# offLNm1         29.616979
# offLNm          29.548174
# offLNm2         29.544833
# offLNm3         29.479960
# playStat        29.297262
# playFNm         29.239377
# gmTime_y        28.856102
# gmTime_x        28.856102
# offFNm3         28.752520
# offFNm          28.709658
# offFNm1         28.699878
# offFNm2         28.674178
# opptLoc_y       28.390681
# teamConf_y      28.390681
# opptConf_x      28.390681
# opptLoc_x       28.390681
# teamLoc_x       28.390681
# teamConf_x      28.390681
# opptConf_y      28.390681
# opptRslt_x      28.158365
# opptRslt_y      28.158365
#                   ...
# teamFGM          3.723368
# teamFGA          3.723368
# teamPF           3.723368
# poss             3.723368
# ...

# %%
data.columns
# Out:
# Index(['gmDate', 'gmTime_x', 'seasTyp', 'playLNm', 'playFNm', 'teamAbbr',
#        'teamConf_x', 'teamDiv_x', 'teamLoc_x', 'teamRslt_x',
#        ...
#        'opptFIC40', 'opptOrtg', 'opptDrtg', 'opptEDiff', 'opptPlay%', 'opptAR',
#        'opptAST/TO', 'opptSTL/TO', 'poss', 'pace'],
#       dtype='object', length=204)

# %%
data.seasTyp.unique()
# Out:
# array(['Regular'], dtype=object)

# %%
data = data.drop(['Regular',],axis=1)

# %%
data[data['offLNm1'] == 'Richardson']
# Out:
#             gmDate gmTime_x  seasTyp      playLNm    playFNm teamAbbr  \
# 873     2012-11-02    19:00  Regular       George       Paul      IND
# 874     2012-11-02    19:00  Regular       George       Paul      IND
# 875     2012-11-02    19:00  Regular       George       Paul      IND
# 876     2012-11-02    19:00  Regular         West      David      IND
# 877     2012-11-02    19:00  Regular         West      David      IND
# 878     2012-11-02    19:00  Regular         West      David      IND
# 879     2012-11-02    19:00  Regular         Hill     George      IND
# 880     2012-11-02    19:00  Regular         Hill     George      IND
# 881     2012-11-02    19:00  Regular         Hill     George      IND
# 882     2012-11-02    19:00  Regular        Green     Gerald      IND
# 883     2012-11-02    19:00  Regular        Green     Gerald      IND
# 884     2012-11-02    19:00  Regular        Green     Gerald      IND
# ...
